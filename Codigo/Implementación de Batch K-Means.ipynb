# %%
import pandas as pd
import seaborn as sns

from sklearn.cluster import MiniBatchKMeans

# %%
import warnings
warnings.simplefilter("ignore")

# %%
df_accidentes = pd.read_csv("C:/Users/sergi/modalidad/X.csv", encoding = 'utf-8')

# %% [markdown]
# # Aprendizaje no supervisado

# %%
kmeans = MiniBatchKMeans(n_clusters=4, batch_size=8).fit(X)
print(f'Total de centros {len(kmeans.cluster_centers_)}')
print("="*34)
print(f'Arreglo con la longitud {kmeans.predict(X)}')
# Out:
# Total de centros 4
# ...
# Arreglo con la longitud [3 3 2 ... 0 0 0]

# %%
df_accidentes['group'] = kmeans.predict(X)

df_accidentes.head(10)
# Out:
#            X         Y  OBJECTID   RADICADO  PERIODO  MES   DIA  group
# 0 -75.596093  6.256489  709812.0  1674223.0   2019.0  6.0   9.0      3
# 1 -75.583161  6.250155  709813.0  1675562.0   2019.0  6.0  21.0      3
# 2 -75.563856  6.250657  709814.0  1661788.0   2019.0  2.0  27.0      2
# 3 -75.576757  6.268025  709815.0  1675911.0   2019.0  6.0  25.0      3
# 4 -75.571897  6.202827  709816.0  1673388.0   2019.0  6.0   4.0      3
# 5 -75.576737  6.207613  709817.0  1666474.0   2019.0  4.0   5.0      3
# 6 -75.609766  6.257146  709818.0  1660673.0   2019.0  2.0  18.0      2
# 7 -75.563572  6.293681  709819.0  1655464.0   2019.0  1.0   1.0      2
# 8 -75.571333  6.255336  709820.0  1672593.0   2019.0  5.0  29.0      3
# 9 -75.576701  6.243748  709821.0  1669539.0   2019.0  5.0   3.0      3

# %%
df_accidentes.to_csv("C:/Users/sergi/modalidad/K-Means.csv", index = False)

# %%
accidentes = pd.read_csv("C:/Users/sergi/modalidad/K-Means.csv")

# %% [markdown]
# # Visualizacion de la agrupación de los cluster

# %%
sns.pairplot(accidentes, hue='group')
